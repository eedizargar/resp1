# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_sales=pd.read_csv('sales data-set.csv')

# %%
df_stores=pd.read_csv('stores data-set.csv')

# %%
df_features=pd.read_csv('Features data set.csv')

# %%
df_sales
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  05/02/2010      24924.50      False
# 1           1     1  12/02/2010      46039.49       True
# 2           1     1  19/02/2010      41595.55      False
# 3           1     1  26/02/2010      19403.54      False
# 4           1     1  05/03/2010      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  28/09/2012        508.37      False
# 421566     45    98  05/10/2012        628.10      False
# 421567     45    98  12/10/2012       1061.02      False
# 421568     45    98  19/10/2012        760.01      False
# 421569     45    98  26/10/2012       1076.80      False
#
# [421570 rows x 5 columns]

# %%
df_stores
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# ...

# %%
df_features
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  05/02/2010        42.31       2.572        NaN        NaN
# 1         1  12/02/2010        38.51       2.548        NaN        NaN
# 2         1  19/02/2010        39.93       2.514        NaN        NaN
# 3         1  26/02/2010        46.63       2.561        NaN        NaN
# 4         1  05/03/2010        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  28/06/2013        76.05       3.639    4842.29     975.03
# 8186     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 8187     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 8188     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 8189     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
df_features['Date']=pd.to_datetime(df_features['Date'])

# %%
df_sales['Date']=pd.to_datetime(df_sales['Date'])

# %%
df_main=pd.merge(df_features,df_sales,on=['Store','Date','IsHoliday'],how='left')
df_main
# Out:
#         Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0           1 2010-05-02        42.31       2.572        NaN        NaN
# 1           1 2010-05-02        42.31       2.572        NaN        NaN
# 2           1 2010-05-02        42.31       2.572        NaN        NaN
# 3           1 2010-05-02        42.31       2.572        NaN        NaN
# 4           1 2010-05-02        42.31       2.572        NaN        NaN
# ...       ...        ...          ...         ...        ...        ...
# 423320     45 2013-06-28        76.05       3.639    4842.29     975.03
# 423321     45 2013-05-07        77.50       3.614    9090.48    2268.58
# 423322     45 2013-12-07        79.37       3.614    3789.94    1827.31
# 423323     45 2013-07-19        82.84       3.737    2961.49    1047.07
# 423324     45 2013-07-26        76.06       3.804     212.02     851.73
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# ...

# %%
df_main=pd.merge(df_main,df_stores,on=['Store'],how='left')

# %%
df_main
# Out:
#         Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0           1 2010-05-02        42.31       2.572        NaN        NaN
# 1           1 2010-05-02        42.31       2.572        NaN        NaN
# 2           1 2010-05-02        42.31       2.572        NaN        NaN
# 3           1 2010-05-02        42.31       2.572        NaN        NaN
# 4           1 2010-05-02        42.31       2.572        NaN        NaN
# ...       ...        ...          ...         ...        ...        ...
# 423320     45 2013-06-28        76.05       3.639    4842.29     975.03
# 423321     45 2013-05-07        77.50       3.614    9090.48    2268.58
# 423322     45 2013-12-07        79.37       3.614    3789.94    1827.31
# 423323     45 2013-07-19        82.84       3.737    2961.49    1047.07
# 423324     45 2013-07-26        76.06       3.804     212.02     851.73
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# ...

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 423325 entries, 0 to 423324
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         423325 non-null  int64
#  1   Date          423325 non-null  datetime64[ns]
#  2   Temperature   423325 non-null  float64
#  3   Fuel_Price    423325 non-null  float64
#  4   MarkDown1     152433 non-null  float64
#  5   MarkDown2     112532 non-null  float64
#  6   MarkDown3     138658 non-null  float64
#  7   MarkDown4     136466 non-null  float64
#  8   MarkDown5     153187 non-null  float64
#  9   CPI           422740 non-null  float64
#  10  Unemployment  422740 non-null  float64
#  11  IsHoliday     423325 non-null  bool
#  12  Dept          421570 non-null  float64
#  13  Weekly_Sales  421570 non-null  float64
#  14  Type          423325 non-null  object
#  15  Size          423325 non-null  int64
# ...

# %%
types,Type=pd.factorize(df_main['Type'])

# %%
df_main['Type']=types

# %%
df_main['Type']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 423320    1
# 423321    1
# 423322    1
# 423323    1
# 423324    1
# Name: Type, Length: 423325, dtype: int64

# %%
df_main.info()
ts1=df_main.set_index('Date')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 423325 entries, 0 to 423324
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         423325 non-null  int64
#  1   Date          423325 non-null  datetime64[ns]
#  2   Temperature   423325 non-null  float64
#  3   Fuel_Price    423325 non-null  float64
#  4   MarkDown1     152433 non-null  float64
#  5   MarkDown2     112532 non-null  float64
#  6   MarkDown3     138658 non-null  float64
#  7   MarkDown4     136466 non-null  float64
#  8   MarkDown5     153187 non-null  float64
#  9   CPI           422740 non-null  float64
#  10  Unemployment  422740 non-null  float64
#  11  IsHoliday     423325 non-null  bool
#  12  Dept          421570 non-null  float64
#  13  Weekly_Sales  421570 non-null  float64
#  14  Type          423325 non-null  int64
#  15  Size          423325 non-null  int64
# dtypes: bool(1), datetime64[ns](1), float64(11), int64(3)
# ...

# %%
df_main[['Store','Date','Temperature','Fuel_Price','MarkDown1','MarkDown2','MarkDown3','MarkDown4','MarkDown5','CPI','Unemployment','Weekly_Sales']].plot(x='Date',subplots=True,figsize=(20,40))
plt.show()

# %%
ts1.loc['2010-01':'2010-07','Weekly_Sales'].max()
# Out:
# 293966.05

# %%
ts1.loc['2010-07':'2011-01','Weekly_Sales'].max()
# Out:
# 693099.36

# %%
ts1.loc['2011-01':'2012-01','Weekly_Sales'].max()
# Out:
# 649770.18

# %%
a=(ts1['Weekly_Sales']==649770.18)
b=(ts1['Weekly_Sales']==293966.05)
c=(ts1['Weekly_Sales']==693099.36)

# %%
ts1[a]
# Out:
#             Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# Date
# 2011-11-25     35        47.88       3.492    1333.24        NaN   58563.24
#
#             MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  Dept  \
# Date
# 2011-11-25      20.97    6386.86  140.421786         8.745       True  72.0
#
#             Weekly_Sales  Type    Size
# Date
# 2011-11-25     649770.18     1  103681

# %%
df_main=df_main.fillna(0)

# %%
df_main['Weekly_Sales']=df_main['Weekly_Sales'].astype(int)

# %%
ts1[b]
# Out:
#             Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# Date
# 2010-05-02     14        27.31       2.784        NaN        NaN        NaN
#
#             MarkDown4  MarkDown5        CPI  Unemployment  IsHoliday  Dept  \
# Date
# 2010-05-02        NaN        NaN  181.87119         8.992      False  92.0
#
#             Weekly_Sales  Type    Size
# Date
# 2010-05-02     293966.05     0  200898

# %%
ts1[c]
# Out:
#             Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# Date
# 2010-11-26     10        55.33       3.162        NaN        NaN        NaN
#
#             MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  Dept  \
# Date
# 2010-11-26        NaN        NaN  126.669267         9.003       True  72.0
#
#             Weekly_Sales  Type    Size
# Date
# 2010-11-26     693099.36     1  126512

# %%
ts3=ts1.resample('W').sum()

# %%
ts1
# Out:
#             Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# Date
# 2010-05-02      1        42.31       2.572        NaN        NaN        NaN
# 2010-05-02      1        42.31       2.572        NaN        NaN        NaN
# 2010-05-02      1        42.31       2.572        NaN        NaN        NaN
# 2010-05-02      1        42.31       2.572        NaN        NaN        NaN
# 2010-05-02      1        42.31       2.572        NaN        NaN        NaN
# ...           ...          ...         ...        ...        ...        ...
# 2013-06-28     45        76.05       3.639    4842.29     975.03       3.00
# 2013-05-07     45        77.50       3.614    9090.48    2268.58     582.74
# 2013-12-07     45        79.37       3.614    3789.94    1827.31      85.72
# 2013-07-19     45        82.84       3.737    2961.49    1047.07     204.19
# 2013-07-26     45        76.06       3.804     212.02     851.73       2.06
#
# ...

# %%
ts3['Weekly_Sales'].max()
# Out:
# 104755337.7499997

# %%
t= ts3['Weekly_Sales']==104755337.7499997

# %%
ts3[t]
# Out:
#              Store  Temperature  Fuel_Price     MarkDown1  MarkDown2  \
# Date
# 2012-06-10  132262    404464.44   22080.081  4.510006e+07  568523.17
#
#             MarkDown3    MarkDown4    MarkDown5           CPI  Unemployment  \
# Date
# 2012-06-10  307187.17  18809666.04  34696786.45  1.040066e+06     43478.862
#
#             IsHoliday      Dept  Weekly_Sales  Type       Size
# Date
# 2012-06-10          0  264954.0  1.047553e+08  3521  810400781

# %%
len(ts1)
# Out:
# 423325
